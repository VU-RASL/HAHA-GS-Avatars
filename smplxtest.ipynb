# %%
import smplx
from smplx.utils import Struct
import pickle

# %%
s = smplx.create('./data','smplx',use_pca=True)

# %%
s.left_hand_pose.shape
# Out:
# torch.Size([1, 6])

# %%
with open('data/smplx/SMPLX_NEUTRAL.pkl', 'rb') as smplh_file:
    model_data = pickle.load(smplh_file, encoding='latin1')

# %%
data = Struct(**model_data)

# %%
data.hands_componentsl[:s.num_pca_comps]
# Out:
# array([[-6.50028279e-03, -4.34437953e-02,  1.04521647e-01,
#         -4.29003164e-02, -1.14816511e-02,  3.07647675e-01,
#          1.49907125e-02,  6.44985437e-02,  1.10806957e-01,
#          1.85078800e-01, -7.47554079e-02,  3.75300169e-01,
#         -1.60148796e-02, -2.95763668e-02,  3.00404191e-01,
#         -1.44586703e-02,  3.20061222e-02,  2.30333954e-01,
#          5.60463369e-01,  1.04981132e-01,  5.39793372e-01,
#         -4.86145355e-02,  5.77444024e-02,  2.19257504e-01,
#          2.10020378e-01, -2.16414910e-02,  1.63890034e-01,
#          2.00091422e-01,  7.32680261e-02,  5.30998588e-01,
#          1.23277120e-01,  6.22607507e-02,  2.26086199e-01,
#          5.39835095e-02, -1.16911260e-02,  2.36914366e-01,
#         -1.24909498e-01, -9.01470631e-02, -3.41816358e-02,
#          1.12301059e-01,  1.11692145e-01,  8.61832965e-03,
#         -7.71658495e-02, -2.68597398e-02, -4.00217846e-02],
#        [-6.11077324e-02,  2.87602935e-02,  8.52101594e-02,
# ...
